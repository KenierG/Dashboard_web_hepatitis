# %%
import pandas as pd
from google.colab import drive
import numpy as np

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/diplomado unicesmag/hepatitis.csv', header=0)
df
# Out:
#      class  age  sex  steroid  antivirals  fatigue  malaise  anorexia  \
# 0        2   30    2        1           2        2        2         2
# 1        2   50    1        1           2        1        2         2
# 2        2   78    1        2           2        1        2         2
# 3        2   34    1        2           2        2        2         2
# 4        2   34    1        2           2        2        2         2
# ..     ...  ...  ...      ...         ...      ...      ...       ...
# 137      1   46    1        2           2        1        1         1
# 138      2   44    1        2           2        1        2         2
# 139      2   61    1        1           2        1        1         2
# 140      2   53    2        1           2        1        2         2
# 141      1   43    1        2           2        1        2         2
#
#      liver_big  liver_firm  spleen_palable  spiders  ascites  varices  \
# ...

# %%
N=df.shape[0]
N
# Out:
# 142

# %%
len(df.columns)
# Out:
# 20

# %%
for column in df:
  c=df[np.isnan(df[column])].shape[0]
  p=1-c/N
  print(column,c,p*100)
# Out:
# class 0 100.0
# age 0 100.0
# sex 0 100.0
# steroid 0 100.0
# antivirals 0 100.0
# fatigue 0 100.0
# malaise 0 100.0
# anorexia 0 100.0
# liver_big 0 100.0
# liver_firm 0 100.0
# spleen_palable 0 100.0
# spiders 0 100.0
# ascites 0 100.0
# varices 0 100.0
# bilirubin 0 100.0
# alk_phosphate 0 100.0
# sgot 0 100.0
# albumin 0 100.0
# protime 0 100.0
# histology 0 100.0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# %%
# Seleccionar características (variables independientes)
X = df[[	'steroid',	'antivirals',		'bilirubin',	'alk_phosphate',	'sgot'	,'albumin'	,'protime'	]]
Y = df[['fatigue'	,'malaise',	'anorexia',	'liver_big',	'liver_firm'	,'spleen_palable'	,'spiders',	'ascites'	,'varices'				,		'histology']]

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.05, random_state=42)

# %%
# Inicializar el modelo de regresión lineal
model = LinearRegression()

# Entrenar el modelo
model.fit(X_train, Y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = model.predict(X_test)

# Evaluar el modelo
mse = mean_squared_error(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)

print("Error cuadrático medio (MSE):", mse)
print("Coeficiente de determinación (R²):", r2)
# Out:
# Error cuadrático medio (MSE): 0.12777862442553825
# Coeficiente de determinación (R²): 0.2917937118626826

# %%
results = pd.DataFrame({
                        'Real_sex': Y_test['sex'],
                        'Predicted_sex': y_pred[:,0],
                        'Real_fatigue': Y_test['fatigue'],
                        'Predicted_fatigue': y_pred[:,1],
                        'Real_malaise': Y_test['malaise'],
                        'Predicted_malaise': y_pred[:,2],
                        'Real_anorexia': Y_test['anorexia'],
                        'Predicted_anorexia': y_pred[:,3],
                        'Real_liver_big': Y_test['liver_big'],
                        'Predicted_liver_big': y_pred[:,4],
                        'Real_liver_firm': Y_test['liver_firm'],
                        'Predicted_liver_firm': y_pred[:,5],
                        'Real_spleen_palable': Y_test['spleen_palable'],
                        'Predicted_spleen_palable': y_pred[:,6],
                        'Real_spiders': Y_test['spiders'],
                        'Predicted_spiders': y_pred[:,7],
                        'Real_ascites': Y_test['ascites'],
                        'Predicted_ascites': y_pred[:,8],
                        'Real_varices': Y_test['varices'],
                        'Predicted_varices': y_pred[:,9],
                        'Real_histology': Y_test['histology'],
                        'Predicted_histology': y_pred[:,10]})

# Imprimir o visualizar los resultados
print(results)

# %% [markdown]
# #guardar modelo

# %%
import joblib

# %%
path="/content/drive/MyDrive/diplomado unicesmag/model"

# %%
import joblib

# Guardar el modelo y sus pesos en un archivo
joblib.dump(model, path+'modelo_regresion_lineal.pkl')
# Out:
# ['/content/drive/MyDrive/diplomado unicesmag/modelmodelo_regresion_lineal.pkl']
